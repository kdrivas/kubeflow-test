# %%
# %cd ..
# Out:
# C:\Users\RONALD\RimacProjects\coe-iaaa-kfp-pipelines-executions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from aikfp.ingestamg_simulation import *
pd.set_option('display.max_columns',None)

# %%
df_train,df_prod=read_datasets('churn-empresas')

# %%
ml=automl_training('churn-empresas',df_train.sample(22000))

# %%
mg=save_metadata_mg_exp('churn-empresas',df_prod,ml)
# Out:
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
