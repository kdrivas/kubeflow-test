# %%
# %cd /home/jupyter/projects/coe-iaaa-kfp-pipelines-executions
# Out:
# /home/jupyter/projects/coe-iaaa-kfp-pipelines-executions

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from aikfp.ingestamg_simulation import *
pd.set_option('display.max_columns',None)
# Out:
# 2022-07-19 20:35:07.086088: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.7/site-packages/cv2/../../lib64:
# 2022-07-19 20:35:07.086140: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#df_train,df_prod=read_datasets('churn-empresas')
ml=automl_training('churn-empresas',df_train.sample(42000))
# Out:
# [Pipeline] .... (step 1 of 2) Processing categoric_null, total=   0.2s
# [I 2022-07-19 20:51:25,767] A new study created in memory with name: LGB Classifier
# [Pipeline] ...... (step 2 of 2) Processing categoric_le, total=   2.7s
# [Pipeline] .... (step 1 of 1) Processing categoric_skip, total=   0.0s
# Using categorical_feature in Dataset.
# Overriding the parameters from Reference Dataset.
# categorical_column in param dict is overridden.
# ...

# %%
ml.preprocess
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('cat',
#                                  Pipeline(steps=[('categoric_null',
#                                                   transformer_cat_null()),
#                                                  ('categoric_le',
#                                                   transformer_cat_le())],
#                                           verbose=True),
#                                  ['ext_ciiu_v4', 'des_provincia',
#                                   'segmento_cliente', 'des_departamento',
#                                   'des_ubigeo', 'des_grupo_economico',
#                                   'id_producto', 'cer_id_ramo',
#                                   'des_tamano_empresa_2', 'ext_sector_empresa',...
#                                   'cal_per_dif_3m', 'cal_dud',
#                                   'cal_dud_dif_12m', 'cal_ok_dif_6m', 'cal_cpp',
# ...

# %%
ml.dict_model
# Out:
# LGBMClassifier(bagging_seed=60, cat_l2=870.3941084254116,
#                cat_smooth=557.6207264215695,
#                colsample_bytree=0.6698480947168615, force_col_wise=True,
#                learning_rate=0.09, max_bin=440, max_cat_threshold=90,
#                max_cat_to_onehot=54, max_depth=8, metric='binary_logloss',
#                min_child_samples=5186, min_child_weight=419.3682222579231,
#                min_split_gain=0.8663597144347683, n_estimators=1000, n_jobs=1,
#                num_classes=1, num_leaves=129, objective='binary',
#                path_smooth=852.8568962666866, random_state=60,
#                reg_alpha=0.02414095646926431, reg_lambda=0.04436533589659018,
#                subsample=0.4057194433139394, verbose=-1)

# %%
display(ml.artifacts['costs'])
ml.artifacts['metadata']
# Out:
#                    periodo time_acum modulename levelname  \
# 0  2022-07-19 20:43:11.927  1235096       root      INFO
# 1  2022-07-19 20:43:13.547  1236716       root      INFO
# 2  2022-07-19 20:43:14.580  1237749       root      INFO
# 3  2022-07-19 20:43:15.268  1238437       root      INFO
# 4  2022-07-19 20:43:16.675  1239844       root      INFO
# ..                     ...       ...        ...       ...
# 76 2022-07-19 20:52:44.737  1807906       root      INFO
# 77 2022-07-19 20:52:44.738  1807907       root      INFO
# 78 2022-07-19 20:52:44.739  1807908       root      INFO
# 79 2022-07-19 20:52:55.783  1818952       root      INFO
# 80 2022-07-19 20:52:55.784  1818953       root      INFO
#
#                                               message  memory_usage_total  \
# 0                         Cfg de entrenamiento creado        7.837159e+09
# 1   Tipo_Preprocess: cat - ['null', 'le'], cont - ...        7.837159e+09
# ...
